# %% [markdown]
# <a href="https://colab.research.google.com/github/allhoesnobros/experiment-13/blob/main/experiment13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Unit 3
# Data Wrangling
# Experiment 13
# To perform processing on a dataset and dealing with missing values

# %%
import pandas as pd
import numpy as np
df1=pd.DataFrame({'c1':[11,21,np.nan],'C2':[15,np.nan,np.nan],'C3':[10,20,30]})
df1
# Out:
#      c1    C2  C3
# 0  11.0  15.0  10
# 1  21.0   NaN  20
# 2   NaN   NaN  30

# %%
df1.isna()
# Out:
#       c1     C2     C3
# 0  False  False  False
# 1  False   True  False
# 2   True   True  False

# %%
df1.notna()
# Out:
#       c1     C2    C3
# 0   True   True  True
# 1   True  False  True
# 2  False  False  True

# %%
#columnwise na values
df1.isna().sum()
# Out:
# c1    1
# C2    2
# C3    0
# dtype: int64

# %%
df1.isna().sum(axis=1)
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
df1.dropna()
# Out:
#      c1    C2  C3
# 0  11.0  15.0  10

# %%
df1.fillna(value='DEFAULT')
# Out:
#         c1       C2  C3
# 0     11.0     15.0  10
# 1     21.0  DEFAULT  20
# 2  DEFAULT  DEFAULT  30

# %%
df1.fillna(value='0')
# Out:
#      c1    C2  C3
# 0  11.0  15.0  10
# 1  21.0     0  20
# 2     0     0  30

# %%
#mean values of columns are calculated
df1.fillna(df1.mean())
# Out:
#      c1    C2  C3
# 0  11.0  15.0  10
# 1  21.0  15.0  20
# 2  16.0  15.0  30

# %%
df1.isna().sum(axis=1)
# Out:
# 0    0
# 1    1
# 2    2
# dtype: int64

# %%
#processing on datasheet-1
import pandas as pd

data = {
    "Roll No": [101, 102, 103, 104, 105],
    "Name": ["Asha", "Rohan", "Meera", "Karan", "Anil"],
    "Age": [20, "-", 21, 20, "22"],
    "Marks": [85, 90, "-", 88, 76],
    "Department": ["CSE", "IT", "CSE", "cse", "E&TC"],
    "Admission_Date": ["01-06-2023", "03-06-2023", "05-06-2023", "07-06-2023", "10/06/23"]
}

df = pd.DataFrame(data)
df
# Out:
#    Roll No   Name Age Marks Department Admission_Date
# 0      101   Asha  20    85        CSE     01-06-2023
# 1      102  Rohan   -    90         IT     03-06-2023
# 2      103  Meera  21     -        CSE     05-06-2023
# 3      104  Karan  20    88        cse     07-06-2023
# 4      105   Anil  22    76       E&TC       10/06/23

# %%
df.replace("-", np.nan, inplace=True)
df
# Out:
#    Roll No   Name  Age  Marks Department Admission_Date
# 0      101   Asha   20   85.0        CSE     01-06-2023
# 1      102  Rohan  NaN   90.0         IT     03-06-2023
# 2      103  Meera   21    NaN        CSE     05-06-2023
# 3      104  Karan   20   88.0        cse     07-06-2023
# 4      105   Anil   22   76.0       E&TC       10/06/23

# %%
# step 2 : replace '-' with NaN to mark missing values

df.replace('-', np.nan, inplace=True)

# convert columns to numeric where needed

df["Age"] = pd.to_numeric(df["Age"], errors='coerce')
df["Marks"] = pd.to_numeric(df["Marks"], errors='coerce')

print(df)
# Out:
#    Roll No   Name   Age  Marks Department Admission_Date
# 0      101   Asha  20.0   85.0        CSE     01-06-2023
# 1      102  Rohan   NaN   90.0         IT     03-06-2023
# 2      103  Meera  21.0    NaN        CSE     05-06-2023
# 3      104  Karan  20.0   88.0        cse     07-06-2023
# 4      105   Anil  22.0   76.0       E&TC       10/06/23

# %%
# step 3: check missing values

print("Missing Values")
print(df.isnull().sum())
# Out:
# Missing Values
# Roll No           0
# Name              0
# Age               1
# Marks             1
# Department        0
# Admission_Date    0
# dtype: int64

# %%
# Fill the Age with mean

df["Age"].fillna(df["Age"].mean(), inplace= True)
print(df)
# Out:
#    Roll No   Name    Age  Marks Department Admission_Date
# 0      101   Asha  20.00   85.0        CSE     01-06-2023
# 1      102  Rohan  20.75   90.0         IT     03-06-2023
# 2      103  Meera  21.00    NaN        CSE     05-06-2023
# 3      104  Karan  20.00   88.0        cse     07-06-2023
# 4      105   Anil  22.00   76.0       E&TC       10/06/23
# /tmp/ipykernel_20552/628588619.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Age"].fillna(df["Age"].mean(), inplace= True)

# %%
# fill the marks with median

df["Marks"].fillna(df["Marks"].median(), inplace=True)
print(df)
# Out:
#    Roll No   Name    Age  Marks Department Admission_Date
# 0      101   Asha  20.00   85.0        CSE     01-06-2023
# 1      102  Rohan  20.75   90.0         IT     03-06-2023
# 2      103  Meera  21.00   86.5        CSE     05-06-2023
# 3      104  Karan  20.00   88.0        cse     07-06-2023
# 4      105   Anil  22.00   76.0       E&TC       10/06/23
# /tmp/ipykernel_20552/1390030300.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Marks"].fillna(df["Marks"].median(), inplace=True)

# %%
# step 4: Fix inconsistent text formatting

df["Department"] = df["Department"].str.upper()
print(df)
# Out:
#    Roll No   Name    Age  Marks Department Admission_Date
# 0      101   Asha  20.00   85.0        CSE     01-06-2023
# 1      102  Rohan  20.75   90.0         IT     03-06-2023
# 2      103  Meera  21.00   86.5        CSE     05-06-2023
# 3      104  Karan  20.00   88.0        CSE     07-06-2023
# 4      105   Anil  22.00   76.0       E&TC       10/06/23

# %%
# step 5: convert admission date to standard datetime format

df["Admission_Date"] = pd.to_numeric(df["Admission_Date"], errors='coerce')
print(df)
# Out:
#    Roll No   Name    Age  Marks Department  Admission_Date
# 0      101   Asha  20.00   85.0        CSE             NaN
# 1      102  Rohan  20.75   90.0         IT             NaN
# 2      103  Meera  21.00   86.5        CSE             NaN
# 3      104  Karan  20.00   88.0        CSE             NaN
# 4      105   Anil  22.00   76.0       E&TC             NaN
